# %% [markdown]
# List & set

# %% [markdown]
# a = 10

# %%
a = ["Pune" , "Sinhgad" , "Raigad" ]
a.append("lohgad")

# %%
a.append("Rajgad")

# %%
a
# Out:
# ['Pune', 'Sinhgad', 'Raigad', 'lohgad', 'Rajgad']

# %%
a.insert(0 , "Mumbai")

# %%
a
# Out:
# ['Mumbai', 'Pune', 'Sinhgad', 'Raigad', 'lohgad']

# %%
a.pop(4)
# Out:
# 'lohgad'

# %%
a
# Out:
# ['Mumbai', 'Pune', 'Sinhgad', 'Raigad']

# %%
# A list of scientific terms used in Japanese, 
# transliterated into English (Rōmaji) alongside their meanings.

words = [
    "Kagaku (Chemistry)",
    "Butsurigaku (Physics)",
    "Seibutzugaku (Biology)",
    "Uchuugaku (Astronomy)",
    "Chishitsugaku (Geology)",
    "Idengaku (Genetics)",
    "Shinkaron (Evolution)",
    "Saibou (Cell)",
    "Bunshi (Molecule)",
    "Atomu (Atom)",
    "Ryoushiki (Quantum)",
    "Juuryoku (Gravity)",
    "Taisha (Metabolism)",
    "Kou合sei (Photosynthesis)",
    "Shinkou (Oscillation)"
]

# %%
words
# Out:
# ['Kagaku (Chemistry)',
#  'Butsurigaku (Physics)',
#  'Seibutzugaku (Biology)',
#  'Uchuugaku (Astronomy)',
#  'Chishitsugaku (Geology)',
#  'Idengaku (Genetics)',
#  'Shinkaron (Evolution)',
#  'Saibou (Cell)',
#  'Bunshi (Molecule)',
#  'Atomu (Atom)',
#  'Ryoushiki (Quantum)',
#  'Juuryoku (Gravity)',
#  'Taisha (Metabolism)',
#  'Kou合sei (Photosynthesis)',
#  'Shinkou (Oscillation)']

# %%
words.pop(3)
# Out:
# 'Uchuugaku (Astronomy)'

# %%
words
# Out:
# ['Kagaku (Chemistry)',
#  'Butsurigaku (Physics)',
#  'Seibutzugaku (Biology)',
#  'Chishitsugaku (Geology)',
#  'Idengaku (Genetics)',
#  'Shinkaron (Evolution)',
#  'Saibou (Cell)',
#  'Bunshi (Molecule)',
#  'Atomu (Atom)',
#  'Ryoushiki (Quantum)',
#  'Juuryoku (Gravity)',
#  'Taisha (Metabolism)',
#  'Kou合sei (Photosynthesis)',
#  'Shinkou (Oscillation)']

# %%
words.pop(-2)
# Out:
# 'Kou合sei (Photosynthesis)'

# %%
words
# Out:
# ['Kagaku (Chemistry)',
#  'Butsurigaku (Physics)',
#  'Seibutzugaku (Biology)',
#  'Chishitsugaku (Geology)',
#  'Idengaku (Genetics)',
#  'Shinkaron (Evolution)',
#  'Saibou (Cell)',
#  'Bunshi (Molecule)',
#  'Atomu (Atom)',
#  'Ryoushiki (Quantum)',
#  'Juuryoku (Gravity)',
#  'Taisha (Metabolism)',
#  'Shinkou (Oscillation)']

# %%
other_words = words.copy()

# %%
other_words
# Out:
# ['Kagaku (Chemistry)',
#  'Butsurigaku (Physics)',
#  'Seibutzugaku (Biology)',
#  'Chishitsugaku (Geology)',
#  'Idengaku (Genetics)',
#  'Shinkaron (Evolution)',
#  'Saibou (Cell)',
#  'Bunshi (Molecule)',
#  'Atomu (Atom)',
#  'Ryoushiki (Quantum)',
#  'Juuryoku (Gravity)',
#  'Taisha (Metabolism)',
#  'Shinkou (Oscillation)']

# %%
words.pop(1)
# Out:
# 'Butsurigaku (Physics)'

# %%
a = ["japan" , "uganda" ]
b = a.copy()

# %%
print(a)
print(b)
# Out:
# ['japan', 'uganda']
# ['japan', 'uganda']

# %%
a.append("Black panther")

# %%
print(a)
print(b)
# Out:
# ['japan', 'uganda', 'Black panther']
# ['japan', 'uganda']

# %%
team_1 = ["Cap A" , "Bucky" , "Panther"]
team_2 = ["Ironman" , "Spider Man", "Vision"]

# %%
team_1.append(team_2)

# %%
team_1
# Out:
# ['Cap A', 'Bucky', 'Panther', ['Ironman', 'Spider Man', 'Vision']]

# %%
team_1 = ["rohit", "ishan" , "surya"]
team_2 = ["MSD" , "jadeja", "Ruturaj"]

# %%
team_1.append(team_2)

# %%
team_1
# Out:
# ['rohit', 'ishan', 'surya', ['MSD', 'jadeja', 'Ruturaj']]

# %%
team_1[3][0]
# Out:
# 'MSD'

# %%
team_1 = ["rohit", "ishan" , "surya"]
team_2 = ["MSD" , "jadeja", "Ruturaj"]

# %%
team_1.extend(team_2)

# %%
team_1
# Out:
# ['rohit', 'ishan', 'surya', 'MSD', 'jadeja', 'Ruturaj']

# %%
raj = ["Chips", "cookies" , "Coke"]
rahul = ["Fruits" , "water"]

# %%
rahul.extend(raj)

# %%
rahul
# Out:
# ['Fruits', 'water', 'Chips', 'cookies', 'Coke']

# %%
a = ["books" , "pen", "Mobile" , "charger" , "netflix" ,   "headphone" , "pen"]

# %%
a.count("netflix")
# Out:
# 1

# %%
a = ["Bike" , "Car" , "Auto" , "Cycle"]

# %%
a.sort(reverse=True)
a
# Out:
# ['Cycle', 'Car', 'Bike', 'Auto']

# %%
a.reverse()
a
# Out:
# ['Cycle', 'Car', 'Bike', 'Auto']

# %%
a = [1,2,3,45,6,7,5,34,245,3,54,634,24,26]
a.sort(reverse= True)
a
# Out:
# [634, 245, 54, 45, 34, 26, 24, 7, 6, 5, 3, 3, 2, 1]

# %%
a = [1,2,3,45,6,7,5,34,245,3,54,634,24,26]
a.reverse()
a
# Out:
# [26, 24, 634, 54, 3, 245, 34, 5, 7, 6, 45, 3, 2, 1]

# %%
a = {"soda" , 'coke' , "soda" , "Milk" , "rice" , "water" , "Fruits"}

# %%
a
# Out:
# {'Fruits', 'Milk', 'coke', 'rice', 'soda', 'water'}
